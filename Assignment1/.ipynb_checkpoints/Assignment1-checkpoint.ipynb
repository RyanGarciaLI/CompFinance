# %% [markdown]
# # Assignment 1

# %%
import pandas as pd
import numpy as np

# %%
stock_data = pd.read_excel("stock data.xlsx", sheet_name="stock prices")
stock_data
# Out:
#           date      1      5     16   288    388    823   883   2020    2269  \
# 0   2020-12-31  54.50  40.65  100.1  6.53  430.0  70.85  7.22  123.0  102.00
# 1   2021-01-04  55.65  40.45  103.3  6.72  441.8  71.75  7.05  127.0  103.20
# 2   2021-01-05  56.00  40.15  106.6  7.17  457.0  73.10  7.06  129.4  101.90
# 3   2021-01-06  56.10  41.50  106.6  7.06  449.0  72.75  7.36  132.8   98.00
# 4   2021-01-07  57.00  43.40  106.6  6.89  443.0  71.45  7.25  130.7   94.95
# ..         ...    ...    ...    ...   ...    ...    ...   ...    ...     ...
# 489 2022-12-22  46.40  48.20  105.5  4.58  337.4  56.35  9.81  102.4   52.35
# 490 2022-12-23  46.20  47.90  105.9  4.52  340.0  56.25  9.81  102.8   54.05
# 491 2022-12-28  47.25  48.50  105.2  4.63  342.6  56.60  9.98  103.0   57.80
# 492 2022-12-29  46.55  48.40  104.8  4.55  340.0  56.80  9.94  101.3   59.55
# 493 2022-12-30  46.85  48.55  106.8  4.54  337.2  57.30  9.98  102.3   59.85
#
#       2628  Hang Seng Index
# ...

# %% [markdown]
# # Question 1

# %%
stock_list = [header for header in stock_data.keys() if type(header) == int]
stock_list
# Out:
# [1, 5, 16, 288, 388, 823, 883, 2020, 2269, 2628]

# %% [markdown]
# ### i. Annualized standard deviation of daily return

# %%
# Q1(i)
from pandas.core.frame import DataFrame
daily_rtn = {}
for stock in stock_list:
    stock_price = stock_data[stock]
    d_rtn = (stock_price - stock_price.shift(1)) / stock_price.shift(1)
    daily_rtn[stock] = d_rtn.dropna()
daily_rtn = DataFrame(daily_rtn)

annual_std = daily_rtn.std() * np.sqrt(252)
print("Annualized standard deviation of daily return:\n{}".format(annual_std))
# Out:
# Annualized standard deviation of daily return:
# 1       0.223032
# 5       0.270614
# 16      0.219267
# 288     0.344421
# 388     0.374930
# 823     0.206004
# 883     0.341776
# 2020    0.503890
# 2269    0.717496
# 2628    0.279728
# dtype: float64

# %% [markdown]
# ### ii. Annualized covariance between each pair of stocks

# %%
sigma_ab = daily_rtn.cov() * 252
sigma_ab
# Out:
#           1         5         16        288       388       823       883   \
# 1     0.049743  0.030958  0.023659  0.029536  0.027147  0.020743  0.027686
# 5     0.030958  0.073232  0.022884  0.026684  0.028928  0.019345  0.032829
# 16    0.023659  0.022884  0.048078  0.026797  0.027710  0.024729  0.017800
# 288   0.029536  0.026684  0.026797  0.118626  0.045703  0.022501  0.028920
# 388   0.027147  0.028928  0.027710  0.045703  0.140573  0.027722  0.035926
# 823   0.020743  0.019345  0.024729  0.022501  0.027722  0.042438  0.015949
# 883   0.027686  0.032829  0.017800  0.028920  0.035926  0.015949  0.116811
# 2020  0.030402  0.024309  0.029086  0.049858  0.113357  0.023953  0.040711
# 2269  0.022637  0.015773  0.029542  0.052833  0.143236  0.031102  0.046113
# 2628  0.031330  0.035252  0.022620  0.038260  0.059114  0.022837  0.040165
#
#           2020      2269      2628
# 1     0.030402  0.022637  0.031330
# 5     0.024309  0.015773  0.035252
# 16    0.029086  0.029542  0.022620
# ...

# %% [markdown]
# ### iii. Correlation coefficient between each pair of stocks.

# %%
rho_ab = daily_rtn.corr()
rho_ab
# Out:
#           1         5         16        288       388       823       883   \
# 1     1.000000  0.512935  0.483796  0.384503  0.324636  0.451469  0.363202
# 5     0.512935  1.000000  0.385660  0.286297  0.285114  0.347002  0.354947
# 16    0.483796  0.385660  1.000000  0.354827  0.337070  0.547474  0.237527
# 288   0.384503  0.286297  0.354827  1.000000  0.353917  0.317128  0.245681
# 388   0.324636  0.285114  0.337070  0.353917  1.000000  0.358923  0.280361
# 823   0.451469  0.347002  0.547474  0.317128  0.358923  1.000000  0.226528
# 883   0.363202  0.354947  0.237527  0.245681  0.280361  0.226528  1.000000
# 2020  0.270519  0.178268  0.263251  0.287284  0.600017  0.230755  0.236395
# 2269  0.141459  0.081237  0.187781  0.213794  0.532455  0.210424  0.188044
# 2628  0.502183  0.465696  0.368798  0.397115  0.563644  0.396300  0.420112
#
#           2020      2269      2628
# 1     0.270519  0.141459  0.502183
# 5     0.178268  0.081237  0.465696
# 16    0.263251  0.187781  0.368798
# ...

# %% [markdown]
# # Question 2

# %%
portfolio = pd.read_excel("stock data.xlsx", sheet_name="Consensus Expected return")
portfolio
# Out:
#     Unnamed: 0               Unnamed: 1  expected 1-yr return  Unnamed: 3  \
# 0   stock code                      NaN                   NaN         NaN
# 1            1             CK Hutchison                 0.089         NaN
# 2            5                     HSBC                 0.149         NaN
# 3           16  Sun Hung Kai Properties                 0.121         NaN
# 4          288                 WH Group                 0.107         NaN
# 5          388       Hong Kong Exchange                 0.220         NaN
# 6          823                Link REIT                 0.065         NaN
# 7          883                    CNOOC                 0.165         NaN
# 8         2020              Anta Sports                 0.104         NaN
# 9         2269           Wuxi Biologics                 0.185         NaN
# 10        2628     China Life Insurance                 0.170         NaN
# 11         NaN                      NaN                   NaN         NaN
# ...

# %% [markdown]
# ## i. With Modern Portfolio Theory

# %%
annual_rtn = portfolio["expected 1-yr return"][1:11]
annual_rtn = np.array(annual_rtn)
annual_rtn
# Out:
# array([0.089, 0.149, 0.121, 0.107, 0.22 , 0.065, 0.165, 0.104, 0.185,
#        0.17 ])

# %% [markdown]
# ### i.(a). Find the standard deviation and expected return of an equal weight (EW) portfolio, where all the stocks have a weight wi = 0.1

# %%
weights = np.array([0.1] * len(stock_list))

portfolio_rtn = np.sum(weights * annual_rtn)
portfolio_std = np.sqrt(np.dot(weights.T, np.dot(sigma_ab, weights)))
print("portfolio return: {}".format(portfolio_rtn.round(3)))
print("portfolio standard deviation: {}".format(portfolio_std.round(3)))
# Out:
# portfolio return: 0.138
# portfolio standard deviation: 0.225

# %% [markdown]
# ### i.(b). Find the global minimum variance (MV) portfolio. Give the standard deviation and expected return of the portfolio, and the weights of the stocks.

# %%
import scipy.optimize as sopt
def portfolio_var(weights):
    return np.dot(weights.T, np.dot(sigma_ab, weights))

# boundaries
bounds = tuple((0,1) for x in range(10))
# constraints
cst = ({'type': 'eq', 'fun':lambda x: np.sum(x) - 1})

optb = sopt.minimize(portfolio_var, weights, method="SLSQP", bounds=bounds, constraints=cst)

portfolio_weights = optb['x']
print("Portfolio weights: {}".format(portfolio_weights.round(3)))

portfolio_std = np.sqrt(portfolio_var(portfolio_weights))
print("Portfolio standard deviation: {}".format(portfolio_std.round(3)))

portfolio_rtn = np.sum(portfolio_weights * annual_rtn)
print("Portfolio return: {}".format(portfolio_rtn.round(3)))
# Out:
# Portfolio weights: [0.192 0.09  0.223 0.031 0.    0.355 0.077 0.    0.    0.033]
# Portfolio standard deviation: 0.17
# Portfolio return: 0.102

# %% [markdown]
# ### i.(c). Draw the efficient frontier, short sale not allowed

# %%
import matplotlib.pyplot as plt

def portfolio_return(weights):
    return np.sum(weights * annual_rtn)

target_rtn = np.linspace(0.09, 0.22, 30)
target_var = []
for rtn in target_rtn:
    constraints = ({"type":"eq", "fun":lambda x:portfolio_return(x) - rtn},
           {"type":"eq", "fun":lambda x:sum(x)-1})
    res = sopt.minimize(portfolio_var, 
                       weights, 
                       method = 'SLSQP', 
                       bounds = bounds, 
                       constraints = constraints)
    target_var.append(res['fun'])

target_var = np.array(target_var)

plt.figure(figsize=(8,4))
plt.scatter(target_var, target_rtn, c=target_rtn/target_var, marker="x")
plt.plot(portfolio_std**2, portfolio_rtn, 'y*', markersize=18)
plt.grid(True)
plt.xlabel("Expected Volatility")
plt.ylabel("Expected Return")
# Out:
# Text(0, 0.5, 'Expected Return')

# %% [markdown]
# ### i.(d). Find the optimal portfolio to be combined with the risk free asset, short sale not allowed (corresponds to case (c) above). State the standard deviation and expected return of this portfolio. Give the weights of the stocks.

# %%
risk_free = 0.043
def portfolio_slope(weights):
    rtn = np.sum(weights * annual_rtn) - risk_free
    sigma = np.sqrt(np.dot(weights.T, np.dot(sigma_ab, weights)))
    return -rtn / sigma
    

optd = sopt.minimize(portfolio_slope, 
                    weights, 
                    method = 'SLSQP', 
                    bounds = bounds, 
                    constraints = cst)

portfolio_w = optd['x']
print("stock weight in porfolio",portfolio_w.round(3))
portfolio_std = np.sqrt(portfolio_var(optd['x']))
print("porfolio stander diviation", portfolio_std.round(3))
portfolio_rtn = portfolio_return(optd['x'])
print("porfolio return", portfolio_rtn.round(3))
# Out:
# stock weight in porfolio [0.    0.216 0.205 0.    0.273 0.    0.154 0.    0.    0.152]
# porfolio stander diviation 0.214
# porfolio return 0.168

# %% [markdown]
# ### i.(e) Your company’s analyst has updated her forecast of WH Group and Link REIT, where the expected 1-yr returns of these stocks have changed to 16.90% and 12.70%. Repeat 2(i)(d) above. Comment on the expected and/or unexpected changes in the weights of the stocks.

# %%
risk_free = 0.043
annual_rtn[3] = 0.169
annual_rtn[5] = 0.127

opte = sopt.minimize(portfolio_slope, 
                    weights, 
                    method = 'SLSQP', 
                    bounds = bounds, 
                    constraints = cst)

portfolio_w_new = opte['x']
print("stock weight in porfolio", portfolio_w_new.round(3))
portfolio_std_new = np.sqrt(portfolio_var(opte['x']))
print("porfolio stander diviation", portfolio_std_new.round(3))
portfolio_rtn_new = portfolio_return(opte['x'])
print("porfolio return", portfolio_rtn_new.round(3))

# comment:
# a small change in expected 1-yr returns will generate dramaticallly different change in the weights of stocks.
print("a small change in expected 1-yr returns will generate dramaticallly different change in the weights of stocks.")
# Out:
# stock weight in porfolio [0.    0.167 0.049 0.109 0.212 0.248 0.13  0.    0.    0.086]
# porfolio stander diviation 0.198
# porfolio return 0.163
# a small change in expected 1-yr returns will generate dramaticallly different change in the weights of stocks.

# %% [markdown]
# ## ii. With the Risk-Parity strategy

# %%
# restore data
annual_rtn = portfolio["expected 1-yr return"][1:11]
annual_rtn = np.array(annual_rtn)

# %% [markdown]
# ### ii.(a). Find the optimal ERC portfolio. State the marginal risk contribution of each stock and give the weights of the stocks.

# %%
sigma_ab_list = sigma_ab.values.tolist()
x, y = np.shape(sigma_ab)
def sqp(weights):
    tr = 0
    for i in range(x):
        for j in range(y):
            tr += (np.dot(weights[i], np.dot(sigma_ab_list[i], weights)) - np.dot(weights[j], np.dot(sigma_ab_list[j], weights)))**2
    return tr

cons = ({'type':"eq", 'fun': lambda x: np.sum(x) - 1})
opt_iia = sopt.minimize(sqp, weights, method="SLSQP", bounds=bounds, constraints=cons)

port_w = opt_iia['x']
print("stock weights in portfolio", port_w.round(3))
port_std = np.sqrt(np.dot(np.dot(opt_iia['x'].T, sigma_ab), opt_iia['x']))
port_mri = []
for i in range(x):
    mri = np.dot(sigma_ab_list[i], opt_iia['x']/port_std)
    port_mri.append(mri.round(3))
print("marginal risk contribution", port_mri)
# Out:
# stock weights in portfolio [0.129 0.121 0.137 0.093 0.071 0.144 0.1   0.062 0.049 0.093]
# marginal risk contribution [0.153, 0.165, 0.142, 0.207, 0.268, 0.13, 0.194, 0.322, 0.398, 0.21]

# %% [markdown]
# ### ii.(b). Calculate the leverage factor for the leveraged ERC portfolio, with a standard deviation of the portfolio equal to your answer in 2(i)(a) above. Find the expected return of this portfolio.

# %%
portfolio_std = np.sqrt(np.dot(weights.T, np.dot(sigma_ab, weights)))
leverage_factor =  portfolio_std / port_std
print("Leverage factor: {}".format(leverage_factor.round(3)))
exp_rtn = (portfolio_return(port_w) - risk_free) * leverage_factor + risk_free
print("Expected return: {}".format(exp_rtn.round(3)))
# Out:
# Leverage factor: 1.152
# Expected return: 0.142

# %% [markdown]
# # Question 3

# %%
cons = ({'type':"eq", 'fun': lambda x: np.sum(x) - 1},
       {'type':"eq", 'fun': lambda x: np.sum(x*np.array(annual_rtn)) - exp_rtn},
       {'type':"eq", 'fun': lambda x: np.sqrt(np.dot(x.T, np.dot(sigma_ab,x))) - portfolio_std})
opt_iib = sopt.minimize(sqp, weights, method="SLSQP", bounds=bounds, constraints=cons)

# %%
price_jan_31 = np.array([49.80, 57.95, 111.1, 4.82, 352.4, 60.93, 11.36, 118.4, 65.25, 14.40])
price_feb_21 = np.array([48.15, 57.60, 111.0, 4.72, 329.4, 51.26, 11.62, 104.3, 56.05, 14.02])

hsi_jan_31 = 21843.33
hsi_feb_21 = 20529.49

res_2ia = (((1e6 * weights) / price_jan_31) * price_feb_21).sum()
print("2-i-a portfolio value and percentage return: {}, {}%".format(np.round(res_2ia,3), np.round((res_2ia-1e6)/1e6*100, 3)))
res_2ib = (((1e6 * optb['x']) / price_jan_31) * price_feb_21).sum()
print("2-i-b portfolio value and percentage return: {}, {}%".format(np.round(res_2ib,3), np.round((res_2ib-1e6)/1e6*100, 3)))
res_2id = (((1e6 * optd['x']) / price_jan_31) * price_feb_21).sum()
print("2-i-d portfolio value and percentage return: {}, {}%".format(np.round(res_2id,3), np.round((res_2id-1e6)/1e6*100, 3)))
res_2iia = (((1e6 * opt_iia['x']) / price_jan_31) * price_feb_21).sum()
print("2-ii-a portfolio value and percentage return: {}, {}%".format(np.round(res_2iia,3), np.round((res_2iia-1e6)/1e6*100, 3)))
res_2iib = (((1e6 * opt_iib['x']) / price_jan_31) * price_feb_21).sum()
print("2-ii-b portfolio value and percentage return: {}, {}%".format(np.round(res_2iib,3), np.round((res_2iib-1e6)/1e6*100, 3)))
print("HSI {}%".format(np.round((hsi_feb_21 - hsi_jan_31) / hsi_jan_31 *100,3)))
# Out:
# 2-i-a portfolio value and percentage return: 945162.178, -5.484%
# 2-i-b portfolio value and percentage return: 936869.733, -6.313%
# 2-i-d portfolio value and percentage return: 980231.065, -1.977%
# 2-ii-a portfolio value and percentage return: 950975.107, -4.902%
# 2-ii-b portfolio value and percentage return: 956705.73, -4.329%
# HSI -6.015%
